# %% [markdown]
# # Allen Cell and Structure Segmenter
#
#
# [og project](https://chanzuckerberg.github.io/napari-plugin-alfa-cohort/projects/allen-cell-segmenter.html)
#
#
# ## ML Code
# [github/AllenCell/aisc-ml-segmentation](https://github.com/AllenCell/aics-ml-segmentation)
# [old](https://github.com/AllenInstitute/aics-ml-segmentation)
#
# ## Classic Code
# [github/AllenCell/aics-segmentation](https://github.com/AllenCell/aics-segmentation)
# [old](https://github.com/AllenInstitute/aics-segmentation)
#
# ## Segmenter model zoo
# https://github.com/AllenCell/segmenter_model_zoo
#
# ## Overview
# https://www.allencell.org/segmenter.html
#
#
#
#
# ![overview-2020-12.png](attachment:overview-2020-12.png)
#
#
# ## start here
# https://github.com/AllenCell/aics-ml-segmentation/blob/main/docs/overview.md
#
# https://www.youtube.com/watch?v=5jBSp38ezG8&t=11s
